# %% [markdown]
# # VOLTANDO UMA PASTA PARA TRAZ

# %%
import os
os.chdir("../")

# %% [markdown]
# # PIPELINE EXTRAÇÃO

# %%
from modules.youtube.extract.ytbpy import channel, playlist, utils, video
from modules import db_manager
from datetime import datetime
from jinja2 import Template
import pandas as pd
import yt_dlp
import time
import os

path_sql = "repository\\querys\\operation\\insert\\video.sql"
with open(path_sql, "r", encoding="utf-8") as file:
    sql_query_insert = file.read()
    
with open("repository\\querys\\operation\\read\\playlist.sql", "r", encoding="utf-8") as file:
    sql_query_read = file.read()
    df_playlist = db_manager.read_df(sql_query_read)
   
with open("repository\\querys\\operation\\read\\video.sql", "r", encoding="utf-8") as file:
    sql_query_read = file.read()
    df_videos = db_manager.read_df(sql_query_read)

# %%
for ID_PLAYLIST, ID_GAME in zip(df_playlist["id_playlist"], df_playlist["id_game"]):
    time.sleep(1)
    for video in playlist.get_playlist_info(ID_PLAYLIST, max_results=100)["videos"]:
        ID_VIDEO        = video["video_id"]
        cut = df_videos[df_videos.id_video.isin([ID_VIDEO])]
        if cut.empty:
            URL             = video["url"]
            TITLE           = video["title"]
            ID_PLAYLIST     = ID_PLAYLIST
            ID_GAME         = ID_GAME
            ID_PROPLAYER    = None
            ID_HERO         = None
            # TIME_MOVIE      = video["duration_seconds"] if "duration_seconds" in video else -1
            PUBLISHED_DATE  = video["published_date"] if "published_date" in video else "" 
            
            sql_template        = Template(sql_query_insert)
            rendered_sql        = sql_template.render(
                ID_VIDEO        = ID_VIDEO,
                URL             = URL,
                ID_PLAYLIST     = ID_PLAYLIST,
                ID_GAME         = ID_GAME,
                ID_PROPLAYER    = ID_PROPLAYER,
                ID_HERO         = ID_HERO,
                # TIME_MOVIE      = int(TIME_MOVIE),
                # PUBLISHED_DATE  = PUBLISHED_DATE,
                REGISTER_DATE   = datetime.now().strftime("%Y-%m-%d")
            ).replace("'None'", "NULL").replace("'False'", "FALSE").replace("'True'", "TRUE")
            
            try:
                db_manager.execute_raw(rendered_sql)
                print(f"✓ Video inserido: {TITLE}")
            except Exception as e:
                print(f"Error inserting video data: {e}")
                print(f"SQL: {rendered_sql}")
                db_manager.connection.rollback()
# Out:
# ✓ Video inserido: 🔥 CHAMPION TIER TINKER SUPPORT?! MALADY MAKES IT LOOK EASY 🔥 | Dota 2
# ✓ Video inserido: 🔥 GUNS, FEAR, & WINS! SAVE MUERTA SUPPORT DOMINATES 🔥 | Dota 2
# ✓ Video inserido: 🔥 SUPPORT ZEUS… WITH RIGHT-CLICK?! 🔥 IMMORTAL SUPPORT GOD | Dota 2
# ✓ Video inserido: 🔥 YOU NEVER SEE HIM COMING! RUE RIKI SUPPORT IS LETHAL 🔪 | Dota 2
# ✓ Video inserido: 🔥 “LET HIM COOK!” TOFU DARK WILLOW vs TEAM LIQUID 🔥 | Dota 2 Support
# ✓ Video inserido: 🔥 KATAOMI BANE DESTROYS GRAND FINALS 🔥 “YOU SLEEP, YOU DIE!” | Dota 2
# ✓ Video inserido: 🔥 “YOU CAN’T DIE!” KATAOMI DAZZLE HARD SUPPORT 🔥 | Dota 2
# ✓ Video inserido: 🔥 ANNOYING WINDRANGER = TEAM'S MVP?! SAVE SUPPORT STYLE 🔥 | Dota 2
# ✓ Video inserido: 🔥 GRAND FINALS?! RUBICK SAYS “EZ GAME.” 🔥 Save GRANDMASTER TIER | Dota 2
# ✓ Video inserido: 🔥 PAINTS THE MAP WITH PAIN! IMMORTAL GRIMSTROKE SUPPORT 🔥 | Dota 2
# ✓ Video inserido: 🔥 SUPPORT CLOCKWERK IS TOO OP?! IMMORTAL CONTROL GOD 🔥 | Dota 2
# ✓ Video inserido: 🔥 SUPPORT SPIRIT BREAKER IS ACTUALLY INSANE?! 🔥 IMMORTAL GRANDMASTER | Dota 2
# ✓ Video inserido: 🔥 INSTANT SWAPS = INSTANT DEATH 🔥 IMMORTAL VENGEFUL SPIRIT SUPPORT | Dota 2
# ✓ Video inserido: Juggernaut Gameplay Miracle with 19 Kills and Manta - Dota 7.39
# ✓ Video inserido: Anti-Mage Gameplay Miracle with 16 Kills and Radiance - Dota 7.39
# ✓ Video inserido: Ember Spirit Gameplay Miracle with 29 Kills and SNY - Dota 7.39
# ✓ Video inserido: Invoker Gameplay Miracle with 19 Kills and Hurricane - Dota 7.39
# ✓ Video inserido: Wraith King Gameplay Miracle with 21 Kills and Silveredge - Dota 7.39
# ✓ Video inserido: Elder Titan Gameplay Miracle with 17 Kills and Shiv - Dota 7.39
# ✓ Video inserido: Juggernaut Gameplay Miracle with 20 Kills and Butterfly - Dota 7.39
# ✓ Video inserido: Riki Gameplay Miracle with 18 Kills and Butterfly - Dota 7.39
# ✓ Video inserido: Templar Assassin Gameplay Miracle with 18 Kills and Shiv - Dota 7.39
# ✓ Video inserido: Drow Ranger Gameplay Miracle with 18 Kills and 948 GPM - Dota 7.39
# ✓ Video inserido: Huskar Gameplay Miracle with 23 Kills and Hurricane - Dota 7.39
# ✓ Video inserido: Shadow Fiend Gameplay Miracle with 21 Kills and Orchid - Dota 7.39
# ✓ Video inserido: Spectre Gameplay Miracle with 27 Kills and 1003 GPM - Dota 7.39
# ✓ Video inserido: Axe Gameplay Miracle with 19 Kills and Silveredge - Dota 7.39
# ✓ Video inserido: Queen of Pain Gameplay Miracle with 20 Kills and Vyse - Dota 7.39
# ✓ Video inserido: Sniper Gameplay Miracle with 22 Kills and 905 GPM - Dota 7.39
# ✓ Video inserido: Outworld Destroyer Gameplay Miracle with 22 Kills and Midas - Dota 7.39
# ✓ Video inserido: Invoker Gameplay Miracle with 31 Kills and Linkens - Dota 7.39
# ✓ Video inserido: Shadow Fiend Gameplay Miracle with Swift and 900 XPM - Dota 7.39
# ✓ Video inserido: Slark Gameplay Miracle with 20 Kills and Skadi - Dota 7.39
# ✓ Video inserido: Faceless Void Gameplay Miracle with Manta and Mjolnir - Dota 7.39
# ✓ Video inserido: Phantom Assassin Gameplay Miracle with 26 Kills and 994 GPM - Dota 7.39
# ✓ Video inserido: Lifestealer Gameplay Miracle with 21 Kills and 979 GPM - Dota 7.39
# ✓ Video inserido: Tinker Gameplay Miracle with 31 Kills and Dagon - Dota 7.39
# ✓ Video inserido: Wraith King Gameplay Miracle with 21 Kills and Silveredge - Dota 7.39
# ✓ Video inserido: Ember Spirit Gameplay Miracle with 29 Kills and SNY - Dota 7.39
# ✓ Video inserido: Queen of Pain Gameplay Miracle with 20 Kills and Vyse - Dota 7.39
# ✓ Video inserido: Lifestealer Gameplay Miracle with 21 Kills and 979 GPM - Dota 7.39
# ✓ Video inserido: Riki Gameplay Miracle with 18 Kills and Butterfly - Dota 7.39
# ✓ Video inserido: Tinker Gameplay Miracle with 31 Kills and Dagon - Dota 7.39
# ✓ Video inserido: Sniper Gameplay Miracle with 22 Kills and 905 GPM - Dota 7.39
# ✓ Video inserido: Anti-Mage Gameplay Miracle with 16 Kills and Radiance - Dota 7.39
# ✓ Video inserido: Huskar Gameplay Miracle with 23 Kills and Hurricane - Dota 7.39
# ✓ Video inserido: Elder Titan Gameplay Miracle with 17 Kills and Shiv - Dota 7.39
# ✓ Video inserido: Phantom Assassin Gameplay Miracle with 26 Kills and 994 GPM - Dota 7.39
# ✓ Video inserido: Slark Gameplay Miracle with 20 Kills and Skadi - Dota 7.39
# ✓ Video inserido: Faceless Void Gameplay Miracle with Manta and Mjolnir - Dota 7.39
# ✓ Video inserido: Templar Assassin Gameplay Miracle with 18 Kills and Shiv - Dota 7.39
# ✓ Video inserido: Drow Ranger Gameplay Miracle with 18 Kills and 948 GPM - Dota 7.39
# ✓ Video inserido: Spectre Gameplay Miracle with 27 Kills and 1003 GPM - Dota 7.39
# ✓ Video inserido: Invoker Gameplay Miracle with 19 Kills and Hurricane - Dota 7.39
# ✓ Video inserido: Invoker Gameplay Miracle with 31 Kills and Linkens - Dota 7.39
# ✓ Video inserido: Juggernaut Gameplay Miracle with 19 Kills and Manta - Dota 7.39
# ✓ Video inserido: Juggernaut Gameplay Miracle with 20 Kills and Butterfly - Dota 7.39
# ✓ Video inserido: Shadow Fiend Gameplay Miracle with 21 Kills and Orchid - Dota 7.39
# ✓ Video inserido: Shadow Fiend Gameplay Miracle with Swift and 900 XPM - Dota 7.39
# ✓ Video inserido: Outworld Destroyer Gameplay Miracle with 22 Kills and Midas - Dota 7.39
# ✓ Video inserido: Ame Shadow Fiend Nevermore Maestro - Dota 2 Pro Gameplay [Watch & Learn]
# ✓ Video inserido: Dota 2 WTF Moments 591
# ✓ Video inserido: The Only Way To Play Anti Mage This Patch in Dota 2
# ✓ Video inserido: No Mercy Slark 25 Kills with CRAZY AGGRESSIVE BUILD Dota 2
# ✓ Video inserido: MIRANA POS 1 Max Attack Speed Build Unreal Damage Dota 2
# ✓ Video inserido: LUNA MID IS REAL – First Item Scepter 100% Cancer Build Dota 2
# ✓ Video inserido: DROW RANGER IS A MONSTER – OP PHYSICAL BUILD Dota 2
# ✓ Video inserido: RAID BOSS AXE 100% BLOCK – 28 KILLS Destroy Pub Game Dota 2
# ✓ Video inserido: Gorgc watches 3 LEGENDS REUNITED: Puppey, N0tail & KuroKy share stories
# ✓ Video inserido: Juggernaut Carry - Playing for Omnishash
# ✓ Video inserido: New JUNE 30, 2025 Giveaway Result and How to Claim the Prize For the Winner
# ✓ Video inserido: How to Solo Mid Shadow Shaman with 1st Item OC 2nd Item Refresher Super Push Mass Serpent Ward DotA
# ✓ Video inserido: How to Solo Mid BH Against Ember 15Min Rampage First Item Max Level Dagon 1 Shot Shuriken Dota 2
# ✓ Video inserido: Arteezy Exposes Enemy Map Hacker! (You Won't Believe This)
# ✓ Video inserido: Arteezy vs. Yatoro: Who is the ULTIMATE Carry King?
# ✓ Video inserido: Arteezy Shadow Fiend: When Even RTZ Can't Carry!
# ✓ Video inserido: Arteezy Exposes Enemy Map Hacker! (You Won't Believe This)
# ✓ Video inserido: Arteezy vs. Yatoro: Who is the ULTIMATE Carry King?
# ✓ Video inserido: Arteezy Shadow Fiend: When Even RTZ Can't Carry!
# ✓ Video inserido: CATACYSM COMBO!! Epic Grandmaster Invoker vs Puck Mid | Dota 2 Invoker
# ✓ Video inserido: NO CHANCE!! Invoker Completely DEMOLISHES Necrophos Mid | Dota 2 Invoker
# ✓ Video inserido: "16 y/o NIKU destroyed MANGEKYOU's Best Hero BROODMOTHER in ranked.."
# ✓ Video inserido: "MIERO LAST PICK AXE, DESTROYING GAIMIN GLADIATORS IN GRANDFINALS!"
# ✓ Video inserido: "GPK~ PUCK SHOW in GRANDFINALS against GAIMIN GLADIATORS.."
# ✓ Video inserido: Hoot Wraith SUPER ACTION - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Lystic Yamato KATANA MASTER 20 KILLS - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Top Rank Vyper MVP PLAYER - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Pulsar Kelvin FROZEN MONSTER - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Top Rank Lady Geist UNKILLABLE SLAYER 19\0\12 - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Sharyk Mirage TORNADO MAKER - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Lystic Yamato KATANA MASTER 20 KILLS - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Azj Infernus FIRE MONSTER - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Pulsar Lash SUPER CRUSHER - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Vegas Bebop KILLING MACHINE 21 KILLS - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Dimov Bebop GET OVER HERE! 20\0\14 - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Hoot Wraith SUPER ACTION - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Haley Warden TOYING ENEMIES 15\0\10 - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: Full Synchro Vindicta EPIC SHOOTER - Deadlock Pro Gameplay & Guides [Watch & Learn]
# ✓ Video inserido: [DOTA 2] GG.Ace BREWMASTER [Gaimin Gladiators vs Team Liquid] [PGL WALLACHIA S5]
# ✓ Video inserido: [DOTA 2] MieRo QUEEN OF PAIN [BETBOOM TEAM vs TEAM LIQUID] [PGL WALLACHIA S5]
# ✓ Video inserido: [DOTA 2] MieRo OMNIKNIGHT [BETBOOM TEAM vs TEAM LIQUID] [PGL WALLACHIA S5]
# ✓ Video inserido: [DOTA 2] SabeRLighT-  DAWNBREAKER [TEAM LIQUID vs BETBOOM TEAM] [PGL WALLACHIA S5]
# ✓ Video inserido: Legion Commander POWERFUL The Underrated Midlane Build Aggressive CARRY - Dota 2
# ✓ Video inserido: OMG! NEW STYLE Phantom Assassin Midlane 1vs5 SAVAGE CARRY - Dota 2
# ✓ Video inserido: Frost Arrows Free Hit DROW RANGER 30 Level How to Won Ranked - Dota 2
# ✓ Video inserido: OMG! NEW STYLE Phantom Assassin Midlane 1vs5 SAVAGE CARRY - Dota 2
# ✓ Video inserido: Frost Arrows Free Hit DROW RANGER 30 Level How to Won Ranked - Dota 2
# ✓ Video inserido: PRO META Spirit Breaker 1 SHOT = GREATER BASH Crazy 7.39 - Dota 2 Pro Ranked Gameplay
# ✓ Video inserido: Legion Commander POWERFUL The Underrated Midlane Build Aggressive CARRY - Dota 2
# ✓ Video inserido: GLADIATORS vs BETBOOM - CRAZY GRANDFINAL ▌WALLACHIA SEASON 5 2025 DOTA 2
# ✓ Video inserido: LIQUID vs BETBOOM - LAST GRANDFINAL SLOT ▌WALLACHIA SEASON 5 2025 DOTA 2
